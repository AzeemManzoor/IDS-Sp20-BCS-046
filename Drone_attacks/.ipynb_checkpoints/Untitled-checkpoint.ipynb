# %%
#import libraries
import geopandas as gpd
import pandas as pd

# %%
#load the dataset (csv file) into the Pandas dataframe
df = pd.read_csv("droneattacks.csv",encoding='latin1')
df.head()
# Out:
#                City Province  No of Strike  Total Died  Injured  Longitude  \
# 0  south Waziristan     FATA           1.0         5.0      NaN    69.9000
# 1  North Waziristan     FATA           1.0         2.0      NaN    70.1455
# 2  North Waziristan     FATA           1.0         5.0      2.0    70.1455
# 3  North Waziristan     FATA           1.0         3.0      2.0    70.1455
# 4    Bajaur  Agency     FATA           1.0        18.0      2.0    71.5000
#
#    Latitude
# 0   33.0333
# 1   32.9746
# 2   32.9746
# 3   32.9746
# 4   34.6833

# %%
#load world map file
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %%
#plot co-ordinates values
dronesmap = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(x=df.Longitude, y=df.Latitude))
dronesmap.plot()
# Out:
# C:\Users\4a\anaconda3\envs\test\lib\site-packages\geopandas\array.py:275: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)
# <AxesSubplot:>

# %%
#plot co-ordinates values on the map
displaymap = dronesmap.set_crs(epsg=4326)
displaymap.crs
displaymap
# Out:
#                     City Province  No of Strike  Total Died  Injured  \
# 0       south Waziristan     FATA           1.0         5.0      NaN
# 1       North Waziristan     FATA           1.0         2.0      NaN
# 2       North Waziristan     FATA           1.0         5.0      2.0
# 3       North Waziristan     FATA           1.0         3.0      2.0
# 4         Bajaur  Agency     FATA           1.0        18.0      2.0
# ..                   ...      ...           ...         ...      ...
# 400                Hangu      KPK           1.0         2.0      0.0
# 401     South Waziristan     FATA           2.0         4.0      0.0
# 402        Kurram Agency     FATA           2.0         3.0      2.0
# 403  Lower Kurram Agency     FATA           4.0        26.0      NaN
# 404                  NaN      NaN           NaN      3658.0   1329.0
#
#      Longitude   Latitude                   geometry
# 0    69.900000  33.033300  POINT (69.90000 33.03330)
# 1    70.145500  32.974600  POINT (70.14550 32.97460)
# 2    70.145500  32.974600  POINT (70.14550 32.97460)
# 3    70.145500  32.974600  POINT (70.14550 32.97460)
# 4    71.500000  34.683300  POINT (71.50000 34.68330)
# ..         ...        ...                        ...
# 400  33.358693  70.540720  POINT (33.35869 70.54072)
# 401  32.120819  69.589987  POINT (32.12082 69.58999)
# 402  33.732174  70.150755  POINT (33.73217 70.15076)
# 403        NaN        NaN            POINT (nan nan)
# 404        NaN        NaN            POINT (nan nan)
#
# [405 rows x 8 columns]
